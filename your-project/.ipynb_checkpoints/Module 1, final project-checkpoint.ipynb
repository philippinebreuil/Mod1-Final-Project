# %%
# Comment faire une boucle pour avoir les données sur chacune de mes villes ? 
# où concerver les données ?

# %% [markdown]
# # Prévisions météorologiques à 16 jours de 77 stations balnéaires Françaises

# %% [markdown]
# Étape 1, scraping de la liste des stations balnéaires Françaises

# %%
# Import des librairies 
import requests
from bs4 import BeautifulSoup
import pandas as pd
from pandas import json_normalize

# %%
# Scapping des noms de stations balnéaires 
website_urls = ['https://www.france-voyage.com/tourisme/stationsbalneaires-panorama_1.htm','https://www.france-voyage.com/tourisme/stationsbalneaires-panorama_2.htm','https://www.france-voyage.com/tourisme/stationsbalneaires-panorama_3.htm','https://www.france-voyage.com/tourisme/stationsbalneaires-panorama_4.htm']
cite_balneaires = []
for urls in website_urls:
    html = requests.get(urls).content
    soup = BeautifulSoup(html, "html")
    cite_table = soup.find_all('div',{'class':'title nolabels'})
    noms = [nom_ville.text.strip() for nom_ville in cite_table]
    cite_balneaires.append(noms)
cite_balneaires = [s for page in cite_balneaires for s in page]

# %%
# Scrapping des noms des départements
departements = []
for urls in website_urls:
    html = requests.get(urls).content
    soup = BeautifulSoup(html, "html")
    departements_table = soup.find_all('div',{'class':'depinfo'})
    noms_dep_1 = [dep.text.strip() for dep in departements_table]
    noms_dep = [dep[:-11] for dep in noms_dep_1]
    departements.append(noms_dep)

departements = [d for pages in departements for d in pages]

# %%
# Créer un dictionnaire avec ville / dept
ville_departement = dict(zip(cite_balneaires ,departements))

# %%
# Transformer en liste d'éléments uniques 
ville_dept_items = ville_departement.items()
ville_dept_list = list(ville_dept_items)
df_ville_dept = pd.DataFrame(ville_dept_list, columns=['ville','departements'])
stations_balneaire = (list(df_ville_dept.ville.unique()))

# %%
df_ville_dept
# Out:
#                          ville          departements
# 0                      Ajaccio          Corse-du-Sud
# 1           Andernos-les-Bains               Gironde
# 2                       Anglet  Pyrénées-Atlantiques
# 3                     Arcachon               Gironde
# 4              Argelès-sur-Mer   Pyrénées-Orientales
# ..                         ...                   ...
# 72      Saint-Valery-sur-Somme                 Somme
# 73                 Sainte-Anne            Martinique
# 74              Soulac-sur-Mer               Gironde
# 75  Vieux-Boucau Port d'Albret                Landes
# 76                    Wimereux         Pas-de-Calais
#
# [77 rows x 2 columns]

# %%
# Noms des sations en majuscule (pour requête API)
stations_balneaire = [x.upper() for x in stations_balneaire]

# %% [markdown]
# Accéder à l'API Weatherbit

# %%
# Import API key
import_key = open('./ignore.txt','r').read()

# %%
# accès à l'API WEATHER FORECAST 
# https://api.weatherbit.io/v2.0/forecast/daily?city=Raleigh,NC&key=API_KEY
api_access = requests.get(f'https://api.weatherbit.io/v2.0/forecast/daily?city=AJACCIO&country=FR&key={import_key}')
#f'{key}'")
api_access
# Out:
# <Response [200]>

# %%
# boucle for pour api request
for station in stations_balneaire :
    df_ville_dept['response']['ville' == station] = requests.get(f'https://api.weatherbit.io/v2.0/forecast/daily?city={station}&country=FR&key={key}')
    df_ville_dept = api_access.json()["data"]
    # Test Philippine
    #df_ville_dept = api_access.json()["data"]
    #df_ville_dept_flattened_data = json_normalize(weather_data)
    #pd.DataFrame(df_ville_dept_flattened_data).set_index('datetime')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/Cellar/jupyterlab/2.1.1/libexec/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'response'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-64e3c9917188> in <module>
#       1 # boucle for pour api request
#       2 for station in stations_balneaire :
# ----> 3     df_ville_dept['response']['ville' == station] = requests.get(f'https://api.weatherbit.io/v2.0/forecast/daily?city={station}&country=FR&key={key}')
#       4     df_ville_dept = api_access.json()["data"]
#       5     # Test Philippine
#
# /usr/local/Cellar/jupyterlab/2.1.1/libexec/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# /usr/local/Cellar/jupyterlab/2.1.1/libexec/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'response'

# %%
weather_data = api_access.json()["data"]
weather_flattened_data = json_normalize(weather_data)
pd.DataFrame(weather_flattened_data).set_index('datetime')
# Out:
#             moonrise_ts wind_cdir  rh      pres  high_temp   sunset_ts  \
# datetime
# 2020-08-01   1596299889         S  51  1005.990       33.3  1596307787
# 2020-08-02   1596389770        SE  65  1003.590       30.4  1596394116
# 2020-08-03   1596479125         S  71  1001.360       27.7  1596480443
# 2020-08-04   1596567976       SSW  63   986.755       25.2  1596566769
# 2020-08-05   1596656408         S  61   992.883       27.3  1596653094
# 2020-08-06   1596744528         S  44   994.921       28.4  1596739417
# 2020-08-07   1596832435         S  49   996.149       29.3  1596825738
# 2020-08-08   1596920212       SSE  59   995.190       28.9  1596912059
# 2020-08-09   1597007934         S  63   993.551       29.3  1596998378
# 2020-08-10   1597095669       SSW  65   993.366       26.4  1597084696
# 2020-08-11   1597097085        SW  62   994.436       25.6  1597171013
# 2020-08-12   1597185059        SW  61   995.219       24.9  1597257328
# 2020-08-13   1597273285         S  56   993.068       25.4  1597343642
# 2020-08-14   1597361868         S  66   988.542       30.7  1597429956
# 2020-08-15   1597450920         S  65   988.821       29.6  1597516268
# 2020-08-16   1597540521         S  70   988.483       28.6  1597602579
#
#               ozone  moon_phase  wind_gust_spd  snow_depth  ...  low_temp  \
# datetime                                                    ...
# 2020-08-01  291.387    0.973294        5.98598           0  ...      21.8
# 2020-08-02  293.327    0.973294        7.08798           0  ...      22.1
# 2020-08-03  306.968    0.996421        9.53200           0  ...      23.1
# 2020-08-04  317.327    0.995786        8.12950           0  ...      18.2
# 2020-08-05  302.283    0.972723        3.72422           0  ...      19.1
# 2020-08-06  300.647    0.929592        3.12634           0  ...      21.9
# 2020-08-07  298.923    0.869366        3.22514           0  ...      22.3
# 2020-08-08  301.932    0.795253        3.70881           0  ...      21.8
# 2020-08-09  293.704    0.710407        2.55228           0  ...      22.3
# 2020-08-10  286.571    0.617781        2.80344           0  ...      25.3
# 2020-08-11  285.515    0.520155        1.30015           0  ...      24.7
# 2020-08-12  278.138    0.420345        1.15567           0  ...      23.6
# 2020-08-13  272.951    0.321537        1.65743           0  ...      23.2
# 2020-08-14  274.186    0.227637        1.60514           0  ...      21.8
# 2020-08-15  292.461    0.143429        1.73200           0  ...      20.9
# 2020-08-16  310.967    0.074360        4.10000           0  ...      23.3
#
#             max_temp  moonset_ts  temp  min_temp  clouds_mid clouds_low  \
# datetime
# 2020-08-01      33.3  1596249877  28.9      22.8           3          0
# 2020-08-02      30.4  1596336277  26.0      21.8           0         16
# 2020-08-03      27.7  1596426458  25.3      22.8           9         44
# 2020-08-04      25.9  1596516761  22.0      17.4           0         26
# 2020-08-05      26.3  1596607050  22.6      18.9           0          1
# 2020-08-06      28.1  1596697250  23.6      19.7           0          0
# 2020-08-07      29.4  1596787344  24.9      21.5           0          0
# 2020-08-08      29.6  1596877357  25.0      21.6           0          0
# 2020-08-09      29.4  1596967330  24.9      20.9           0          0
# 2020-08-10      29.9  1597057312  26.1      21.9           0          0
# 2020-08-11      30.6  1597147343  25.9      23.7           0          0
# 2020-08-12      30.4  1597237440  25.6      23.9           0          0
# 2020-08-13      31.5  1597327584  26.1      23.2           0          0
# 2020-08-14      30.7  1597417699  25.5      21.8           0          0
# 2020-08-15      29.6  1597507658  24.8      20.9           0          0
# 2020-08-16      28.6  1597597318  23.8      23.3           0          0
#
#             weather.icon  weather.code weather.description
# datetime
# 2020-08-01          c02d           801          Few clouds
# 2020-08-02          c02d           801          Few clouds
# 2020-08-03          c03d           803       Broken clouds
# 2020-08-04          c03d           803       Broken clouds
# 2020-08-05          c02d           801          Few clouds
# 2020-08-06          c02d           801          Few clouds
# 2020-08-07          c01d           800           Clear Sky
# 2020-08-08          c01d           800           Clear Sky
# 2020-08-09          c02d           801          Few clouds
# 2020-08-10          c02d           801          Few clouds
# 2020-08-11          c01d           800           Clear Sky
# 2020-08-12          c01d           800           Clear Sky
# 2020-08-13          c01d           800           Clear Sky
# 2020-08-14          c01d           800           Clear Sky
# 2020-08-15          c01d           800           Clear Sky
# 2020-08-16          c03d           803       Broken clouds
#
# [16 rows x 39 columns]

# %%
low_temp = weather_data['iss_position']['low_temp']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-8463fce0090d> in <module>
# ----> 1 low_temp = weather_data['iss_position']['low_temp']
#
# TypeError: list indices must be integers or slices, not str

# %%
# Extraire un type de valeur
max_temp = [d["max_temp"] for d in weather_data]
max_temp
# Out:
# [33.3,
#  30.4,
#  27.7,
#  25.9,
#  26.3,
#  28.1,
#  29.4,
#  29.6,
#  29.4,
#  29.9,
#  30.6,
#  30.4,
#  31.5,
#  30.7,
#  29.6,
#  28.6]

# %% [markdown]
# API AIR QUALITY

# %%
# accès à l'API AIR QUALITY
api_access = requests.get(f'https://api.weatherbit.io/v2.0/history/airquality?city=AJACCIO&country=FR&key={key}')
api_access
# Out:
# <Response [200]>

# %%
air_quality_data = api_access.json()
air_quality_flattened_data = json_normalize(air_quality_data)
air_quality = pd.DataFrame(air_quality_flattened_data).explode('data')
air_quality
# infos de qualité de l'air dans data 
# -> comment garder que aqi: Air Quality Index [US - EPA standard 0 - +500]
# Out:
#                                                 data city_name      lon  \
# 0  {'moonrise_ts': 1596299889, 'wind_cdir': 'S', ...   Ajaccio  8.73462
# 0  {'moonrise_ts': 1596389770, 'wind_cdir': 'SE',...   Ajaccio  8.73462
# 0  {'moonrise_ts': 1596479125, 'wind_cdir': 'S', ...   Ajaccio  8.73462
# 0  {'moonrise_ts': 1596567976, 'wind_cdir': 'SSW'...   Ajaccio  8.73462
# 0  {'moonrise_ts': 1596656408, 'wind_cdir': 'S', ...   Ajaccio  8.73462
# 0  {'moonrise_ts': 1596744528, 'wind_cdir': 'S', ...   Ajaccio  8.73462
# 0  {'moonrise_ts': 1596832435, 'wind_cdir': 'S', ...   Ajaccio  8.73462
# 0  {'moonrise_ts': 1596920212, 'wind_cdir': 'SSE'...   Ajaccio  8.73462
# 0  {'moonrise_ts': 1597007934, 'wind_cdir': 'S', ...   Ajaccio  8.73462
# 0  {'moonrise_ts': 1597095669, 'wind_cdir': 'SSW'...   Ajaccio  8.73462
# 0  {'moonrise_ts': 1597097085, 'wind_cdir': 'SW',...   Ajaccio  8.73462
# 0  {'moonrise_ts': 1597185059, 'wind_cdir': 'SW',...   Ajaccio  8.73462
# 0  {'moonrise_ts': 1597273285, 'wind_cdir': 'S', ...   Ajaccio  8.73462
# 0  {'moonrise_ts': 1597361868, 'wind_cdir': 'S', ...   Ajaccio  8.73462
# 0  {'moonrise_ts': 1597450920, 'wind_cdir': 'S', ...   Ajaccio  8.73462
# 0  {'moonrise_ts': 1597540521, 'wind_cdir': 'S', ...   Ajaccio  8.73462
#
#        timezone       lat country_code state_code
# 0  Europe/Paris  41.92723           FR         94
# 0  Europe/Paris  41.92723           FR         94
# 0  Europe/Paris  41.92723           FR         94
# 0  Europe/Paris  41.92723           FR         94
# 0  Europe/Paris  41.92723           FR         94
# 0  Europe/Paris  41.92723           FR         94
# 0  Europe/Paris  41.92723           FR         94
# 0  Europe/Paris  41.92723           FR         94
# 0  Europe/Paris  41.92723           FR         94
# 0  Europe/Paris  41.92723           FR         94
# 0  Europe/Paris  41.92723           FR         94
# 0  Europe/Paris  41.92723           FR         94
# 0  Europe/Paris  41.92723           FR         94
# 0  Europe/Paris  41.92723           FR         94
# 0  Europe/Paris  41.92723           FR         94
# 0  Europe/Paris  41.92723           FR         94

# %%
print(air_quality['data'])
# Out:
# 0    {'moonrise_ts': 1596299889, 'wind_cdir': 'S', ...
# 0    {'moonrise_ts': 1596389770, 'wind_cdir': 'SE',...
# 0    {'moonrise_ts': 1596479125, 'wind_cdir': 'S', ...
# 0    {'moonrise_ts': 1596567976, 'wind_cdir': 'SSW'...
# 0    {'moonrise_ts': 1596656408, 'wind_cdir': 'S', ...
# 0    {'moonrise_ts': 1596744528, 'wind_cdir': 'S', ...
# 0    {'moonrise_ts': 1596832435, 'wind_cdir': 'S', ...
# 0    {'moonrise_ts': 1596920212, 'wind_cdir': 'SSE'...
# 0    {'moonrise_ts': 1597007934, 'wind_cdir': 'S', ...
# 0    {'moonrise_ts': 1597095669, 'wind_cdir': 'SSW'...
# 0    {'moonrise_ts': 1597097085, 'wind_cdir': 'SW',...
# 0    {'moonrise_ts': 1597185059, 'wind_cdir': 'SW',...
# 0    {'moonrise_ts': 1597273285, 'wind_cdir': 'S', ...
# 0    {'moonrise_ts': 1597361868, 'wind_cdir': 'S', ...
# 0    {'moonrise_ts': 1597450920, 'wind_cdir': 'S', ...
# 0    {'moonrise_ts': 1597540521, 'wind_cdir': 'S', ...
# Name: data, dtype: object
